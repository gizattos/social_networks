# %%
import time
import tweepy
import pandas as pd

# %%
##autenticando
auth = tweepy.OAuthHandler("API key", "API secret key")
auth.set_access_token("Access Token", "Secret Token")
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
dict = {}
i=0
for user in tweepy.Cursor(api.friends, screen_name="gilmarmendes").items():
    dict[i] = {'user':user.screen_name,'nome':user.name,"link":"https://twitter.com/"+user.screen_name,"seguidores":user.followers_count}
    i=i+1
df = pd.DataFrame.from_dict(dict, "index")

# %%
df
# Out:
#                user                nome                                link  \
# 0    50ChicoAlencar       Chico Alencar  https://twitter.com/50ChicoAlencar
# 1         CNNBrasil          CNN Brasil       https://twitter.com/CNNBrasil
# 2      RevistaISTOE       Revista ISTOÉ    https://twitter.com/RevistaISTOE
# 3    valoreconomico     Valor Econômico  https://twitter.com/valoreconomico
# 4    GabrielaPrioli     Gabriela Prioli  https://twitter.com/GabrielaPrioli
# ..              ...                 ...                                 ...
# 138        Int_IDEA  International IDEA        https://twitter.com/Int_IDEA
# 139         SejaIDP                 IDP         https://twitter.com/SejaIDP
# 140     CNJ_oficial                 CNJ     https://twitter.com/CNJ_oficial
# 141     STJnoticias                 STJ     https://twitter.com/STJnoticias
# 142        TSEjusbr                 TSE        https://twitter.com/TSEjusbr
#
#      seguidores
# 0        239999
# 1        835086
# 2       1674140
# 3       2371307
# 4        942753
# ..          ...
# 138       26358
# 139        6072
# 140      860938
# 141      797163
# 142      351596
#
# [143 rows x 4 columns]

# %%
df.to_excel("gilmarmendes.xls")
